# %%
import pandas as pd

# %%
bat = pd.read_csv("All_batters.csv")

# %%
bowl = pd.read_csv('All_bowlers.csv')

# %%
bowl.drop(['Unnamed: 0.1','Unnamed: 0'],axis=1,inplace=True)

# %%
bat = bat[['batsman','ID','got_out','Runs','Balls','Fours','Sixes','St.rate','Inning','Team','Opponent','Win/Lost','match_id','time',
   'day','year','Month','Venue']]

# %%
bat.Venue.unique()
# Out:
# array(['Punjab Cricket Association IS Bindra Stadium, Mohali',
#        'Eden Gardens, Kolkata', 'Sawai Mansingh Stadium, Jaipur',
#        'Rajiv Gandhi International Stadium, Hyderabad',
#        'MA Chidambaram Stadium, Chennai',
#        'M.Chinnaswamy Stadium, Bengaluru', 'Arun Jaitley Stadium, Delhi',
#        'Dr DY Patil Sports Academy, Mumbai', 'Wankhede Stadium, Mumbai',
#        'Newlands, Cape Town', "St George's Park, Port Elizabeth",
#        'Kingsmead, Durban', 'SuperSport Park, Centurion',
#        'Buffalo Park, East London', 'Diamond Oval, Kimberley',
#        'Mangaung Oval, Bloemfontein',
#        'The Wanderers Stadium, Johannesburg', 'Brabourne Stadium, Mumbai',
#        'Narendra Modi Stadium, Ahmedabad', 'Barabati Stadium, Cuttack',
#        'Vidarbha Cricket Association Stadium, Nagpur',
#        'Himachal Pradesh Cricket Association Stadium, Dharamsala',
#        'Maharashtra Cricket Association Stadium, Pune',
# ...

# %%
delhi_st = bat[bat.Venue=='Arun Jaitley Stadium, Delhi']

# %%
delhi_st[delhi_st.ID==1413]
# Out:
#                batsman      ID                 got_out  Runs  Balls  Fours
# 190        Virat Kohli  1413.0     c Jaiswal b Prasidh     1      1      0  \
# 3617       Virat Kohli  1413.0  c Riyan Parag b Ashwin    13     11      1
# 7285   Virat Kohli (c)  1413.0     c Jaiswal b Prasidh    23     17      2
# 8562   Virat Kohli (c)  1413.0             lbw b Boult    70     40      7
# 11197      Virat Kohli  1413.0     c Jaiswal b Prasidh    35     23      6
# 14823      Virat Kohli  1413.0             lbw b Boult    56     38      8
#
#        Sixes  St.rate Inning                         Team          Opponent
# 190        0   100.00   Inn2  Royal Challengers Bangalore  Delhi Daredevils  \
# 3617       0   118.18   Inn2  Royal Challengers Bangalore  Delhi Daredevils
# 7285       1   135.29   Inn2  Royal Challengers Bangalore    Delhi Capitals
# 8562       3   175.00   Inn2  Royal Challengers Bangalore  Delhi Daredevils
# ...
